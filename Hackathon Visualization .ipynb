# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_ipo = pd.read_csv('ipo_2010_2021.csv', parse_dates=True)
df_ipo
#df.drop(['B', 'C'], axis=1)
df_ipo = df_ipo.drop(['Profile'], axis=1)
df_ipo
# Out:
#          Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 0    29-07-21    Tatva Chintan                  500.00    2.55    9.78  13.36
# 1    23-07-21           Zomato                 9375.00   51.79   32.96   7.45
# 2    19-07-21    Clean Science                 1546.00  156.37  206.43   9.00
# 3    19-07-21        G R Infra                  963.28   93.18   73.01   4.89
# 4    07-07-21  India Pesticide                  800.00    2.64    1.36   4.40
# ..        ...              ...                     ...     ...     ...    ...
# 259  19-02-10      Thangamayil                    0.00    0.52    1.52   2.26
# 260  15-02-10  Vascon Engineer                  199.80    1.12    3.65   0.62
# 261  15-02-10    Syncom Health                   56.25    0.99   16.60   6.25
# 262  08-02-10    Jubilant Food                  328.70   59.39   51.95   3.79
# 263  03-02-10    Infinite Comp                  189.80   48.44  106.02  11.08
#
#      Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 0     9.50  1083.0       2111.80        2310.25            113.32  2,268.50
# 1    38.25    76.0        115.00         125.85             65.59    133.35
# 2    93.41   900.0       1784.40        1585.20             76.13  1,682.80
# 3    43.48   837.0       1700.00        1746.80            108.70  1,730.85
# 4     3.25   296.0        360.00         335.45             13.33    337.40
# ..     ...     ...           ...            ...               ...       ...
# 259   1.12    75.0         70.00          71.10             -5.20    870.00
# 260   1.22   165.0        155.90         146.38            -11.28     21.70
# 261   5.17    75.0         88.00          87.85             17.13      4.06
# 262  31.11   145.0        160.00         114.50            -21.03  3,770.20
# 263  43.22   165.0        178.35         184.51             11.82    473.75
#
#      Current  Gains (%)
# 0                109.46
# 1                 75.46
# 2                 86.98
# 3                106.79
# 4                 13.99
# ..                  ...
# 259             1060.00
# 260              -86.85
# 261              -94.59
# 262             2500.14
# 263              187.12
#
# [264 rows x 13 columns]

# %%
df_nifty= pd.read_csv('NIFTY_2010_2021.csv', parse_dates=True)
df_nifty
# Out:
#              Date      Open      High       Low     Close  Shares Traded  \
# 0     04-Jan-2010   5200.90   5238.45   5167.10   5232.20      148652424
# 1     05-Jan-2010   5277.15   5288.35   5242.40   5277.90      240844424
# 2     06-Jan-2010   5278.15   5310.85   5260.05   5281.80      216147837
# 3     07-Jan-2010   5281.80   5302.55   5244.75   5263.10      181246734
# 4     08-Jan-2010   5264.25   5276.75   5234.70   5244.75      201910800
# ...           ...       ...       ...       ...       ...            ...
# 2868  26-Jul-2021  15849.30  15893.35  15797.00  15824.45      267076679
# 2869  27-Jul-2021  15860.50  15881.55  15701.00  15746.45      311012065
# 2870  28-Jul-2021  15761.55  15767.50  15513.45  15709.40      318601589
# 2871  29-Jul-2021  15762.70  15817.35  15737.80  15778.45      401584915
# 2872  30-Jul-2021  15800.60  15862.80  15744.85  15763.05      400021237
#
#       Turnover (Rs. Cr)
# 0               6531.61
# 1               7969.62
# 2               7892.60
# 3               6890.99
# 4               7777.04
# ...                 ...
# 2868           19487.18
# 2869           26117.34
# 2870           26090.48
# 2871           29460.54
# 2872           30539.63
#
# [2873 rows x 7 columns]

# %%
x = df_nifty['Date']
print(x)
# Out:
# 0       04-Jan-2010
# 1       05-Jan-2010
# 2       06-Jan-2010
# 3       07-Jan-2010
# 4       08-Jan-2010
#            ...
# 2868    26-Jul-2021
# 2869    27-Jul-2021
# 2870    28-Jul-2021
# 2871    29-Jul-2021
# 2872    30-Jul-2021
# Name: Date, Length: 2873, dtype: object

# %%
x = pd.to_datetime(df_ipo['Date'])
print(x)
# Out:
# 0     2021-07-29
# 1     2021-07-23
# 2     2021-07-19
# 3     2021-07-19
# 4     2021-07-07
#          ...
# 259   2010-02-19
# 260   2010-02-15
# 261   2010-02-15
# 262   2010-08-02
# 263   2010-03-02
# Name: Date, Length: 264, dtype: datetime64[ns]

# %%
y = pd.to_datetime(df_nifty['Date'])
print(y)
# Out:
# 0      2010-01-04
# 1      2010-01-05
# 2      2010-01-06
# 3      2010-01-07
# 4      2010-01-08
#           ...
# 2868   2021-07-26
# 2869   2021-07-27
# 2870   2021-07-28
# 2871   2021-07-29
# 2872   2021-07-30
# Name: Date, Length: 2873, dtype: datetime64[ns]

# %%
df_ipo['date_std']=x
df_ipo
# Out:
#          Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 0    29-07-21    Tatva Chintan                  500.00    2.55    9.78  13.36
# 1    23-07-21           Zomato                 9375.00   51.79   32.96   7.45
# 2    19-07-21    Clean Science                 1546.00  156.37  206.43   9.00
# 3    19-07-21        G R Infra                  963.28   93.18   73.01   4.89
# 4    07-07-21  India Pesticide                  800.00    2.64    1.36   4.40
# ..        ...              ...                     ...     ...     ...    ...
# 259  19-02-10      Thangamayil                    0.00    0.52    1.52   2.26
# 260  15-02-10  Vascon Engineer                  199.80    1.12    3.65   0.62
# 261  15-02-10    Syncom Health                   56.25    0.99   16.60   6.25
# 262  08-02-10    Jubilant Food                  328.70   59.39   51.95   3.79
# 263  03-02-10    Infinite Comp                  189.80   48.44  106.02  11.08
#
#      Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 0     9.50  1083.0       2111.80        2310.25            113.32  2,268.50
# 1    38.25    76.0        115.00         125.85             65.59    133.35
# 2    93.41   900.0       1784.40        1585.20             76.13  1,682.80
# 3    43.48   837.0       1700.00        1746.80            108.70  1,730.85
# 4     3.25   296.0        360.00         335.45             13.33    337.40
# ..     ...     ...           ...            ...               ...       ...
# 259   1.12    75.0         70.00          71.10             -5.20    870.00
# 260   1.22   165.0        155.90         146.38            -11.28     21.70
# 261   5.17    75.0         88.00          87.85             17.13      4.06
# 262  31.11   145.0        160.00         114.50            -21.03  3,770.20
# 263  43.22   165.0        178.35         184.51             11.82    473.75
#
#      Current  Gains (%)   date_std
# 0                109.46 2021-07-29
# 1                 75.46 2021-07-23
# 2                 86.98 2021-07-19
# 3                106.79 2021-07-19
# 4                 13.99 2021-07-07
# ..                  ...        ...
# 259             1060.00 2010-02-19
# 260              -86.85 2010-02-15
# 261              -94.59 2010-02-15
# 262             2500.14 2010-08-02
# 263              187.12 2010-03-02
#
# [264 rows x 14 columns]

# %% [markdown]
# # Nifty

# %%
df_nifty.parse_date = True

x = pd.to_datetime(df_nifty['Date'])
#print(x)
df_nifty['date_std']=x
df_nifty.set_index('date_std')
col = (df_nifty['date_std'] < '2011-01-01') & (df_nifty['date_std'] >= '2010-01-01')
#df_nifty.loc[col]

# %%
col1 = (df_nifty['date_std'] < '2011-01-01') & (df_nifty['date_std'] >= '2010-01-01')
col2 = (df_nifty['date_std'] < '2012-01-01') & (df_nifty['date_std'] >= '2011-01-01')
col3 = (df_nifty['date_std'] < '2013-01-01') & (df_nifty['date_std'] >= '2012-01-01')
col4 = (df_nifty['date_std'] < '2014-01-01') & (df_nifty['date_std'] >= '2013-01-01')
col5 = (df_nifty['date_std'] < '2015-01-01') & (df_nifty['date_std'] >= '2014-01-01')
col6 = (df_nifty['date_std'] < '2016-01-01') & (df_nifty['date_std'] >= '2015-01-01')
col7 = (df_nifty['date_std'] < '2017-01-01') & (df_nifty['date_std'] >= '2016-01-01')
col8 = (df_nifty['date_std'] < '2018-01-01') & (df_nifty['date_std'] >= '2017-01-01')
col9 = (df_nifty['date_std'] < '2019-01-01') & (df_nifty['date_std'] >= '2018-01-01')
col10 = (df_nifty['date_std'] < '2020-01-01') & (df_nifty['date_std'] >= '2019-01-01')
col11= (df_nifty['date_std'] < '2021-01-01') & (df_nifty['date_std'] >= '2020-01-01')
col12 = (df_nifty['date_std'] >= '2021-01-01')

# %%
list_yearly = []
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col1].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col2].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col3].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col4].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col5].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col6].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col7].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col8].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col9].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col10].sum())
list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col11].sum())
#list_yearly.append(df_nifty['Turnover (Rs. Cr)'].loc[col12].sum())
print(list_yearly)
# Out:
# [1664860.98, 1481640.03, 1477290.1099999999, 1577356.0299999998, 1805916.48, 1989260.49, 2113113.95, 2549346.52, 3539136.3400000003, 4659209.770000001, 7769294.66]

# %%
year=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
stats = list(zip(year,list_yearly))
df1 = pd.DataFrame(stats, columns=['Year', 'Turnover'])
df1
# Out:
#     Year    Turnover
# 0   2010  1664860.98
# 1   2011  1481640.03
# 2   2012  1477290.11
# 3   2013  1577356.03
# 4   2014  1805916.48
# 5   2015  1989260.49
# 6   2016  2113113.95
# 7   2017  2549346.52
# 8   2018  3539136.34
# 9   2019  4659209.77
# 10  2020  7769294.66

# %%
df.to_csv('TurnoverNifty.txt', index=False, header=True)

# %%
plt.xlabel('Year')
plt.ylabel('Turnover')
plt.bar(df1['Year'],df1['Turnover']) # if possible remove last row
# Out:
# <BarContainer object of 11 artists>

# %% [markdown]
# Turnover exponentially increases every year leading to more cashflow and liquidity

# %%
##Stocks Traded
list_yearly_shr = []
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col1].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col2].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col3].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col4].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col5].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col6].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col7].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col8].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col9].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col10].sum())
list_yearly_shr.append(df_nifty['Shares Traded'].loc[col11].sum())
#list_yearly_shr.append(df_nifty['Turnover (Rs. Cr)'].loc[col12].sum())
print(list_yearly_shr)
# Out:
# [41326134816, 35542396262, 38420344095, 41361068057, 37762392451, 41584254781, 49596223105, 50644215971, 67574582712, 118404069321, 166562436173]

# %%
year=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
stats = list(zip(year,list_yearly_shr))
df1 = pd.DataFrame(stats, columns=['Year', 'Shares Traded'])
df1
# Out:
#     Year  Shares Traded
# 0   2010    41326134816
# 1   2011    35542396262
# 2   2012    38420344095
# 3   2013    41361068057
# 4   2014    37762392451
# 5   2015    41584254781
# 6   2016    49596223105
# 7   2017    50644215971
# 8   2018    67574582712
# 9   2019   118404069321
# 10  2020   166562436173

# %%
import seaborn as sns
sns.set(style="whitegrid")
ax = sns.lineplot(df1['Year'],df1['Shares Traded'])

# %% [markdown]
# Shares traded shows that there is more speculation which leads to rise in secondary market.

# %% [markdown]
# # IPO Checks

# %%
df_ipo.parse_date = True
x = pd.to_datetime(df_ipo['Date'])
#print(x)
df_ipo['date_std']=x
df_ipo
df_ipo.set_index('date_std')
# Out:
#                 Date         IPO Name  Issue Size (in crores)     QIB     HNI  \
# date_std
# 2021-07-29  29-07-21    Tatva Chintan                  500.00    2.55    9.78
# 2021-07-23  23-07-21           Zomato                 9375.00   51.79   32.96
# 2021-07-19  19-07-21    Clean Science                 1546.00  156.37  206.43
# 2021-07-19  19-07-21        G R Infra                  963.28   93.18   73.01
# 2021-07-07  07-07-21  India Pesticide                  800.00    2.64    1.36
# ...              ...              ...                     ...     ...     ...
# 2010-02-19  19-02-10      Thangamayil                    0.00    0.52    1.52
# 2010-02-15  15-02-10  Vascon Engineer                  199.80    1.12    3.65
# 2010-02-15  15-02-10    Syncom Health                   56.25    0.99   16.60
# 2010-08-02  08-02-10    Jubilant Food                  328.70   59.39   51.95
# 2010-03-02  03-02-10    Infinite Comp                  189.80   48.44  106.02
#
#               RII  Total   Issue  Listing Open  Listing Close  \
# date_std
# 2021-07-29  13.36   9.50  1083.0       2111.80        2310.25
# 2021-07-23   7.45  38.25    76.0        115.00         125.85
# 2021-07-19   9.00  93.41   900.0       1784.40        1585.20
# 2021-07-19   4.89  43.48   837.0       1700.00        1746.80
# 2021-07-07   4.40   3.25   296.0        360.00         335.45
# ...           ...    ...     ...           ...            ...
# 2010-02-19   2.26   1.12    75.0         70.00          71.10
# 2010-02-15   0.62   1.22   165.0        155.90         146.38
# 2010-02-15   6.25   5.17    75.0         88.00          87.85
# 2010-08-02   3.79  31.11   145.0        160.00         114.50
# 2010-03-02  11.08  43.22   165.0        178.35         184.51
#
#             Listing Gains(%)       CMP  Current  Gains (%)
# date_std
# 2021-07-29            113.32  2,268.50              109.46
# 2021-07-23             65.59    133.35               75.46
# 2021-07-19             76.13  1,682.80               86.98
# 2021-07-19            108.70  1,730.85              106.79
# 2021-07-07             13.33    337.40               13.99
# ...                      ...       ...                 ...
# 2010-02-19             -5.20    870.00             1060.00
# 2010-02-15            -11.28     21.70              -86.85
# 2010-02-15             17.13      4.06              -94.59
# 2010-08-02            -21.03  3,770.20             2500.14
# 2010-03-02             11.82    473.75              187.12
#
# [264 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([50, 35, 15])
mylabels = ["QIB", "RII", "NII"]

plt.pie(y, labels = mylabels)
plt.title("Investment Categories", bbox={'facecolor':'0.8', 'pad':5})

plt.show()

# %%
col_ipo = (df_ipo['date_std'] >= '2021-01-01')
a2021 = df_ipo.loc[col_ipo]
a2021
# Out:
#         Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 0   29-07-21    Tatva Chintan                  500.00    2.55    9.78  13.36
# 1   23-07-21           Zomato                 9375.00   51.79   32.96   7.45
# 2   19-07-21    Clean Science                 1546.00  156.37  206.43   9.00
# 3   19-07-21        G R Infra                  963.28   93.18   73.01   4.89
# 4   07-07-21  India Pesticide                  800.00    2.64    1.36   4.40
# 5   05-07-21    Krishna Inst.                 2146.00    5.26    1.89   2.90
# 6   28-06-21      Dodla Dairy                  521.00   84.88   73.26  11.34
# 7   24-06-21   Shyam Metalics                  909.00   62.18  172.51   5.29
# 8   24-06-21         Sona BLW                 5550.00    1.57    0.22   0.66
# 9   14-05-21  PowerGrid InvIT                 7734.99    0.00    0.00   0.00
# 10  19-04-21    Macrotech Dev                 2500.00    3.05    1.44   0.40
# 11  07-04-21     Barbeque Nat                  453.60    0.00    0.00   0.00
# 12  30-03-21           Nazara                  582.91   52.82  148.42  34.49
# 13  26-03-21   Suryoday Small                  582.34    2.18    1.31   3.09
# 14  26-03-21  Kalyan Jeweller                 1175.00    1.18    0.97   1.47
# 15  25-03-21    Laxmi Organic                  600.00    1.13    0.73   4.41
# 16  25-03-21        Craftsman                  823.70    0.56    0.05   1.04
# 17  24-03-21   Anupam Rasayan                  760.00   30.80   62.06   4.62
# 18  19-03-21        Easy Trip                  510.00    0.00    2.79  14.48
# 19  15-03-21        MTAR Tech                  596.41   52.01  522.35  12.78
# 20  05-03-21          Heranba                   60.00   25.98  108.72   4.82
# 21  26-02-21          Railtel                  819.24   22.03   51.40   7.08
# 22  25-02-21           Nureca                  100.00    0.24   17.10  74.29
# 23  05-02-21      Stove Kraft                  412.63    8.02   32.72  26.04
# 24  03-02-21       Home First                 1153.72   52.53   39.00   6.59
# 25  02-02-21    Indigo Paints                 1170.56   96.21  115.76   6.50
# 26  29-01-21             IRFC                 4633.00    0.89    0.52   1.59
# 27  01-01-21     Antony Waste                  300.53    0.64    0.28   7.22
#
#      Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 0     9.50  1083.0       2111.80        2310.25            113.32  2,268.50
# 1    38.25    76.0        115.00         125.85             65.59    133.35
# 2    93.41   900.0       1784.40        1585.20             76.13  1,682.80
# 3    43.48   837.0       1700.00        1746.80            108.70  1,730.85
# 4     3.25   296.0        360.00         335.45             13.33    337.40
# 5     3.86   825.0       1009.00        1096.80             32.95  1,206.60
# 6    45.62   428.0        550.00         609.10             42.31    617.50
# 7    56.56   306.0        380.00         375.85             22.83    436.10
# 8     1.04   291.0        302.40         362.85             24.69    438.90
# 9     0.00   100.0        104.00         102.98              2.98    119.00
# 10    1.36   486.0        439.00         463.15             -4.70    853.45
# 11    0.00   500.0        492.00         590.40             18.08    878.70
# 12   75.04  1101.0       1971.00        1576.80             43.22  1,850.00
# 13    2.37   305.0        274.75         276.20             -9.44    203.45
# 14    1.28    87.0         73.90          75.30            -13.45     70.90
# 15    2.68   130.0        173.00         164.60             26.62    261.55
# 16    0.69  1490.0       1440.00        1433.00             -3.83  2,001.75
# 17   23.86   555.0        534.70         525.90             -5.24    723.10
# 18    3.39   187.0        182.00         208.30             11.39    408.85
# 19  133.18   575.0        990.05        1082.25             88.22  1,438.85
# 20   33.13   627.0        900.00         812.25             29.55    810.15
# 21   20.68    94.0        109.00         121.40             29.15    139.00
# 22   17.98   400.0        634.95         666.65             66.66  1,728.35
# 23   18.03   385.0        498.00         445.95             15.83    772.15
# 24   26.66   518.0        612.15         527.40              1.81    600.00
# 25   54.84  1490.0       2607.50        3118.65            109.31  2,595.00
# 26    1.16    26.0         25.00          24.85             -4.42     23.00
# 27    3.85   315.0        430.00         407.25             29.29    344.95
#
#     Current  Gains (%)   date_std
# 0               109.46 2021-07-29
# 1                75.46 2021-07-23
# 2                86.98 2021-07-19
# 3               106.79 2021-07-19
# 4                13.99 2021-07-07
# 5                46.25 2021-05-07
# 6                44.28 2021-06-28
# 7                42.52 2021-06-24
# 8                50.82 2021-06-24
# 9                19.00 2021-05-14
# 10               75.61 2021-04-19
# 11               75.74 2021-07-04
# 12               68.03 2021-03-30
# 13              -33.30 2021-03-26
# 14              -18.51 2021-03-26
# 15              101.19 2021-03-25
# 16               34.35 2021-03-25
# 17               30.29 2021-03-24
# 18              118.64 2021-03-19
# 19              150.23 2021-03-15
# 20               29.21 2021-05-03
# 21               47.87 2021-02-26
# 22              332.09 2021-02-25
# 23              100.56 2021-05-02
# 24               15.83 2021-03-02
# 25               74.16 2021-02-02
# 26              -11.54 2021-01-29
# 27                9.51 2021-01-01

# %% [markdown]
# Note: Listing of IPO Sector-wise investment for last 3 years: 2021, 2020, 2019

# %%
sub = (df_ipo['QIB']< 1.0) |(df_ipo['RII']< 1.0)|(df_ipo['HNI']< 1.0)
df_ipo.loc[sub].count()
# Out:
# Date                      116
# IPO Name                  116
# Issue Size (in crores)    116
# QIB                       116
# HNI                       116
# RII                       116
# Total                     116
# Issue                     116
# Listing Open              116
# Listing Close             116
# Listing Gains(%)          116
# CMP                       116
# Current  Gains (%)        115
# date_std                  116
# dtype: int64

# %%
sub1 =  (a2021['Total']< 1.0)
a2021.loc[sub1].count()
a2021.loc[sub1]
# Out:
#         Date         IPO Name  Issue Size (in crores)   QIB   HNI   RII  \
# 9   14-05-21  PowerGrid InvIT                 7734.99  0.00  0.00  0.00
# 11  07-04-21     Barbeque Nat                  453.60  0.00  0.00  0.00
# 16  25-03-21        Craftsman                  823.70  0.56  0.05  1.04
#
#     Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 9    0.00   100.0         104.0         102.98              2.98    119.00
# 11   0.00   500.0         492.0         590.40             18.08    878.70
# 16   0.69  1490.0        1440.0        1433.00             -3.83  2,001.75
#
#     Current  Gains (%)   date_std
# 9                19.00 2021-05-14
# 11               75.74 2021-07-04
# 16               34.35 2021-03-25

# %% [markdown]
# Companies undersubscribed over the year 2021

# %%
sub = (a2021['QIB']>=1.0) |(a2021['RII']>=1.0)|(a2021['HNI']>= 1.0)
sub2 = (a2021['Total']>= 1.0)
print("Companies with overflow",a2021.loc[sub2].count()['CMP'])
a2021.loc[sub2]
# Out:
# Companies with overflow 25
#         Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 0   29-07-21    Tatva Chintan                  500.00    2.55    9.78  13.36
# 1   23-07-21           Zomato                 9375.00   51.79   32.96   7.45
# 2   19-07-21    Clean Science                 1546.00  156.37  206.43   9.00
# 3   19-07-21        G R Infra                  963.28   93.18   73.01   4.89
# 4   07-07-21  India Pesticide                  800.00    2.64    1.36   4.40
# 5   05-07-21    Krishna Inst.                 2146.00    5.26    1.89   2.90
# 6   28-06-21      Dodla Dairy                  521.00   84.88   73.26  11.34
# 7   24-06-21   Shyam Metalics                  909.00   62.18  172.51   5.29
# 8   24-06-21         Sona BLW                 5550.00    1.57    0.22   0.66
# 10  19-04-21    Macrotech Dev                 2500.00    3.05    1.44   0.40
# 12  30-03-21           Nazara                  582.91   52.82  148.42  34.49
# 13  26-03-21   Suryoday Small                  582.34    2.18    1.31   3.09
# 14  26-03-21  Kalyan Jeweller                 1175.00    1.18    0.97   1.47
# 15  25-03-21    Laxmi Organic                  600.00    1.13    0.73   4.41
# 17  24-03-21   Anupam Rasayan                  760.00   30.80   62.06   4.62
# 18  19-03-21        Easy Trip                  510.00    0.00    2.79  14.48
# 19  15-03-21        MTAR Tech                  596.41   52.01  522.35  12.78
# 20  05-03-21          Heranba                   60.00   25.98  108.72   4.82
# 21  26-02-21          Railtel                  819.24   22.03   51.40   7.08
# 22  25-02-21           Nureca                  100.00    0.24   17.10  74.29
# 23  05-02-21      Stove Kraft                  412.63    8.02   32.72  26.04
# 24  03-02-21       Home First                 1153.72   52.53   39.00   6.59
# 25  02-02-21    Indigo Paints                 1170.56   96.21  115.76   6.50
# 26  29-01-21             IRFC                 4633.00    0.89    0.52   1.59
# 27  01-01-21     Antony Waste                  300.53    0.64    0.28   7.22
#
#      Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 0     9.50  1083.0       2111.80        2310.25            113.32  2,268.50
# 1    38.25    76.0        115.00         125.85             65.59    133.35
# 2    93.41   900.0       1784.40        1585.20             76.13  1,682.80
# 3    43.48   837.0       1700.00        1746.80            108.70  1,730.85
# 4     3.25   296.0        360.00         335.45             13.33    337.40
# 5     3.86   825.0       1009.00        1096.80             32.95  1,206.60
# 6    45.62   428.0        550.00         609.10             42.31    617.50
# 7    56.56   306.0        380.00         375.85             22.83    436.10
# 8     1.04   291.0        302.40         362.85             24.69    438.90
# 10    1.36   486.0        439.00         463.15             -4.70    853.45
# 12   75.04  1101.0       1971.00        1576.80             43.22  1,850.00
# 13    2.37   305.0        274.75         276.20             -9.44    203.45
# 14    1.28    87.0         73.90          75.30            -13.45     70.90
# 15    2.68   130.0        173.00         164.60             26.62    261.55
# 17   23.86   555.0        534.70         525.90             -5.24    723.10
# 18    3.39   187.0        182.00         208.30             11.39    408.85
# 19  133.18   575.0        990.05        1082.25             88.22  1,438.85
# 20   33.13   627.0        900.00         812.25             29.55    810.15
# 21   20.68    94.0        109.00         121.40             29.15    139.00
# 22   17.98   400.0        634.95         666.65             66.66  1,728.35
# 23   18.03   385.0        498.00         445.95             15.83    772.15
# 24   26.66   518.0        612.15         527.40              1.81    600.00
# 25   54.84  1490.0       2607.50        3118.65            109.31  2,595.00
# 26    1.16    26.0         25.00          24.85             -4.42     23.00
# 27    3.85   315.0        430.00         407.25             29.29    344.95
#
#     Current  Gains (%)   date_std
# 0               109.46 2021-07-29
# 1                75.46 2021-07-23
# 2                86.98 2021-07-19
# 3               106.79 2021-07-19
# 4                13.99 2021-07-07
# 5                46.25 2021-05-07
# 6                44.28 2021-06-28
# 7                42.52 2021-06-24
# 8                50.82 2021-06-24
# 10               75.61 2021-04-19
# 12               68.03 2021-03-30
# 13              -33.30 2021-03-26
# 14              -18.51 2021-03-26
# 15              101.19 2021-03-25
# 17               30.29 2021-03-24
# 18              118.64 2021-03-19
# 19              150.23 2021-03-15
# 20               29.21 2021-05-03
# 21               47.87 2021-02-26
# 22              332.09 2021-02-25
# 23              100.56 2021-05-02
# 24               15.83 2021-03-02
# 25               74.16 2021-02-02
# 26              -11.54 2021-01-29
# 27                9.51 2021-01-01

# %%
col_ipo1 = (df_ipo['date_std'] < '2011-01-01') & (df_ipo['date_std'] >= '2010-01-01')
col_ipo2 = (df_ipo['date_std'] < '2012-01-01') & (df_ipo['date_std'] >= '2011-01-01')
col_ipo3 = (df_ipo['date_std'] < '2013-01-01') & (df_ipo['date_std'] >= '2012-01-01')
col_ipo4 = (df_ipo['date_std'] < '2014-01-01') & (df_ipo['date_std'] >= '2013-01-01')
col_ipo5 = (df_ipo['date_std'] < '2015-01-01') & (df_ipo['date_std'] >= '2014-01-01')
col_ipo6 = (df_ipo['date_std'] < '2016-01-01') & (df_ipo['date_std'] >= '2015-01-01')
col_ipo7 = (df_ipo['date_std'] < '2017-01-01') & (df_ipo['date_std'] >= '2016-01-01')
col_ipo8 = (df_ipo['date_std'] < '2018-01-01') & (df_ipo['date_std'] >= '2017-01-01')
col_ipo9 = (df_ipo['date_std'] < '2019-01-01') & (df_ipo['date_std'] >= '2018-01-01')
col_ipo10 = (df_ipo['date_std'] < '2020-01-01') & (df_ipo['date_std'] >= '2019-01-01')
col_ipo11= (df_ipo['date_std'] < '2021-01-01') & (df_ipo['date_std'] >= '2020-01-01')
col_ipo12 = (df_ipo['date_std'] >= '2021-01-01')
#df_ipo
#print("bsahcghdsgfka", df_ipo[col_ipo1].count()['CMP'])

# %%
a2020 = df_ipo.loc[col_ipo11]
#a2020
sub1 =  (a2020['Total']< 1.0)
a2020.loc[sub1].count()
a2020.loc[sub1]
# Out:
# Empty DataFrame
# Columns: [Date, IPO Name, Issue Size (in crores), QIB, HNI, RII, Total, Issue, Listing Open, Listing Close, Listing Gains(%), CMP, Current  Gains (%), date_std]
# Index: []

# %%
sub2 =  (a2020['Total']>= 1.0)
a2020.loc[sub2].count()
a2020.loc[sub2]
# Out:
#         Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 28  24-12-20     Bectors Food                  540.54  176.85  620.86  29.33
# 29  14-12-20      Burger King                  796.50   86.64  354.11  68.15
# 30  20-11-20            Gland                 6479.55    6.40    0.51   0.24
# 31  02-11-20     Equitas Bank                  517.60    3.91    0.22   2.08
# 32  12-10-20          UTI AMC                 2159.88    3.34    0.93   2.32
# 33  12-10-20     Mazagon Dock                  443.69   89.71  678.88  35.63
# 34  05-10-20    Angel Broking                  600.00    5.74    0.69   4.31
# 35  01-10-20             CAMS                 2244.33   73.18  111.85   5.55
# 36  01-10-20  Chemcon Special                  318.00  113.54  449.14  41.21
# 37  21-09-20            Route                  600.00   89.76  192.81  12.67
# 38  17-09-20  Happiest Minds                   702.02   77.43  351.46  70.94
# 39  23-07-20          Rossari                  496.25    2.75    4.34   2.51
# 40  16-03-20         SBI Card                10286.20   57.18   45.23   2.50
#
#      Total   Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 28  198.02   288.0        501.00         595.55            106.79    427.90
# 29  156.65    60.0        115.35         138.40            130.67    180.40
# 30    2.06  1500.0       1710.00        1820.45             21.36  3,920.00
# 31    1.95    33.0         31.00          32.75             -0.76     63.20
# 32    2.31   554.0        476.20         476.60            -13.97  1,042.05
# 33  157.41   145.0        216.25         173.00             19.31    259.50
# 34    3.94   306.0        275.00         275.85             -9.85  1,186.85
# 35   46.99  1230.0       1535.00        1401.60             13.95  3,344.45
# 36  149.33   340.0        731.00         584.80             72.00    502.00
# 37   73.30   350.0        708.00         651.10             86.03  2,063.10
# 38  150.98   166.0        351.00         371.00            123.49  1,361.65
# 39    2.97   425.0        670.00         742.35             74.67  1,243.35
# 40   26.54   755.0        658.00         683.20             -9.51  1,036.45
#
#     Current  Gains (%)   date_std
# 28               48.58 2020-12-24
# 29              200.67 2020-12-14
# 30              161.33 2020-11-20
# 31               91.52 2020-02-11
# 32               88.10 2020-12-10
# 33               78.97 2020-12-10
# 34              287.86 2020-05-10
# 35              171.91 2020-01-10
# 36               47.65 2020-01-10
# 37              489.46 2020-09-21
# 38              720.27 2020-09-17
# 39              192.55 2020-07-23
# 40               37.28 2020-03-16

# %%
a2019 = df_ipo.loc[col_ipo10]
#a2019
sub1 =  (a2019['Total']< 1.0)
a2019.loc[sub1].count()
a2019.loc[sub1]
# Out:
#         Date         IPO Name  Issue Size (in crores)   QIB   HNI  RII  Total  \
# 45  20-08-19  Sterling & Wils                  3125.0  1.02  0.89  0.3   0.85
#
#     Issue  Listing Open  Listing Close  Listing Gains(%)     CMP  \
# 45  780.0         700.0         725.35             -7.01  286.10
#
#     Current  Gains (%)   date_std
# 45              -63.32 2019-08-20

# %%
sub2 =  (a2019['Total']>= 1.0)
a2019.loc[sub2].count()
a2019.loc[sub2]
# Out:
#         Date         IPO Name  Issue Size (in crores)     QIB     HNI    RII  \
# 41  30-12-19     Prince Pipes                  500.00    3.54    1.21   1.89
# 42  12-12-19    Ujjivan Small                  750.00  110.72  473.00  49.09
# 43  04-12-19         CSB Bank                  409.68   38.85   45.49   9.01
# 44  14-10-19            IRCTC                  635.04  108.79  354.52  14.94
# 46  04-07-19  Indiamart Inter                  474.12   30.83   62.13  14.07
# 47  08-05-19           Neogen                  131.48   30.49  113.88  16.06
# 48  15-04-19       Metropolis                 1200.18    8.88    3.03   2.21
# 49  11-04-19       Rail Vikas                  430.88    1.36    0.80   2.92
# 50  01-04-19   Embassy Office                 4750.00    2.15    3.09   0.31
# 51  29-03-19             MSTC                  213.81    1.13    2.15   2.95
# 52  07-02-19    Chalet Hotels                 1628.84    4.66    1.10   0.03
# 53  04-02-19  Xelpmoc Design                    23.00    1.24    7.69   2.64
#
#      Total  Issue  Listing Open  Listing Close  Listing Gains(%)       CMP  \
# 41    2.21  178.0        160.00         166.60             -6.40    685.70
# 42  165.68   37.0         58.75          55.90             51.08     28.80
# 43   35.24  195.0        275.00         300.10             53.90    349.80
# 44  111.95  320.0        644.00         728.60            127.69  2,329.60
# 46   36.21  973.0       1180.00        1302.55             33.87  7,135.65
# 47   41.18    0.0        251.00         263.55              0.00    917.00
# 48    5.84  880.0        960.00         959.55              9.04  2,855.00
# 49    1.82   19.0         19.00          19.05              0.26     29.65
# 50    2.57  300.0        300.00         314.10              4.70    362.51
# 51    1.46  128.0        111.00         114.20            -10.78    284.05
# 52    1.57  280.0        291.00         290.40              3.71    176.35
# 53    3.25   66.0         56.00          58.80            -10.91    418.90
#
#     Current  Gains (%)   date_std
# 41              285.22 2019-12-30
# 42              -22.16 2019-12-12
# 43               79.38 2019-04-12
# 44              628.00 2019-10-14
# 46              633.37 2019-04-07
# 47                 NaN 2019-08-05
# 48              224.43 2019-04-15
# 49               56.05 2019-11-04
# 50               20.84 2019-01-04
# 51              121.91 2019-03-29
# 52              -37.02 2019-07-02
# 53              534.70 2019-04-02

# %%
list_gains = []
cond1 = col_ipo1 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond2= col_ipo2 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond3 = col_ipo3 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond4 = col_ipo4 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond5 = col_ipo5 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond6 = col_ipo6 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond7 = col_ipo7 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond8 = col_ipo8 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond9 = col_ipo9 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond10 = col_ipo10 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond11 = col_ipo11 &  (df_ipo['Current  Gains (%)'] > 0.0)
cond12 = col_ipo12 &  (df_ipo['Current  Gains (%)'] > 0.0)
df_ipo[cond1].count()['Current  Gains (%)']
# Out:
# 15

# %%
list_gains.append((df_ipo[cond1].count()['Current  Gains (%)']/(df_ipo[col_ipo1].count()['CMP'])*100))
list_gains.append((df_ipo[cond2].count()['Current  Gains (%)']/(df_ipo[col_ipo2].count()['CMP'])*100))
list_gains.append((df_ipo[cond3].count()['Current  Gains (%)']/(df_ipo[col_ipo3].count()['CMP'])*100))
list_gains.append((df_ipo[cond4].count()['Current  Gains (%)']/(df_ipo[col_ipo4].count()['CMP'])*100))
list_gains.append((df_ipo[cond5].count()['Current  Gains (%)']/(df_ipo[col_ipo5].count()['CMP'])*100))
list_gains.append((df_ipo[cond6].count()['Current  Gains (%)']/(df_ipo[col_ipo6].count()['CMP'])*100))
list_gains.append((df_ipo[cond7].count()['Current  Gains (%)']/(df_ipo[col_ipo7].count()['CMP'])*100))
list_gains.append((df_ipo[cond8].count()['Current  Gains (%)']/(df_ipo[col_ipo8].count()['CMP'])*100))
list_gains.append((df_ipo[cond9].count()['Current  Gains (%)']/(df_ipo[col_ipo9].count()['CMP'])*100))
list_gains.append((df_ipo[cond10].count()['Current  Gains (%)']/(df_ipo[col_ipo10].count()['CMP'])*100))
list_gains.append((df_ipo[cond11].count()['Current  Gains (%)']/(df_ipo[col_ipo11].count()['CMP'])*100))
list_gains.append((df_ipo[cond12].count()['Current  Gains (%)']/(df_ipo[col_ipo12].count()['CMP'])*100))
list_gains
# Out:
# [25.0,
#  14.285714285714285,
#  18.181818181818183,
#  100.0,
#  60.0,
#  35.0,
#  72.0,
#  60.0,
#  52.94117647058824,
#  69.23076923076923,
#  100.0,
#  89.28571428571429]

# %%
year=[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]
stats = list(zip(year,list_gains))
df1 = pd.DataFrame(stats, columns=['Year', 'Gains %age'])
df1
# Out:
#     Year  Gains %age
# 0   2010   25.000000
# 1   2011   14.285714
# 2   2012   18.181818
# 3   2013  100.000000
# 4   2014   60.000000
# 5   2015   35.000000
# 6   2016   72.000000
# 7   2017   60.000000
# 8   2018   52.941176
# 9   2019   69.230769
# 10  2020  100.000000
# 11  2021   89.285714

# %%
plt.xlabel('Year')
plt.ylabel('%age of Companies with Positive Gains ')
plt.bar(df1['Year'],df1['Gains %age'])
# Out:
# <BarContainer object of 12 artists>

# %% [markdown]
# An increase can significantly seen in the number of companies gaining post IPO launches from 2019-2021. This signifies that there is a large amount of not just Investers but traders as well interested to trust a company for its growth.
# 1. Addition of number of startups
# 2. Political influence
# 3. Number of investors increasing

# %% [markdown]
# As of January 2021, the country had a total of 5.15-crore demat accounts, compared with 4.08-crore as of financial year 2020 and
# 3.59-crore as of FY19.
#
# The number of individual investors in the market has increased by a whopping 142 lakh in FY21
#
# Also, the share of individual investors in total turnover on stock exchange has risen to 45% from 39% in Mar’20, as shown by NSE data.

# %%
from matplotlib.pyplot import figure

plt.xlabel('Year')
plt.ylabel('Number of Demat accounts per year in Crore ')
list_yr= ['2019', '2020', '2021']
demat=[3.59, 4.88, 5.15]
investors = list(zip(list_yr,demat))
line_demat = pd.DataFrame(investors, columns=['Year', 'Demat Accounts '])
sns.set(style="whitegrid")
#ax = sns.lineplot(line_demat['Year'],line_demat['Demat Accounts '])
plt.bar(line_demat['Year'],line_demat['Demat Accounts '])
# Out:
# <BarContainer object of 3 artists>

# %%
df_sectors = pd.read_excel('sectors.xlsx')
df_sectors = df_sectors.set_index('Company')

df_ipo_un = pd.read_csv('ipo_2010_2021.csv')
df_ipo_un = df_ipo_un.set_index('IPO Name')

df_merged = df_ipo_un.merge(df_sectors, left_index=True, right_index=True)

display(df_sectors)
# Out:
#                                        Sector
# Company
# Tatva Chintan             Specialty Chemicals
# Zomato            Internet & Catalogue Retail
# Clean Science             Specialty Chemicals
# G R Infra          Construction & Engineering
# India Pesticide                 Agrochemicals
# Krishna Inst.           Healthcare Facilities
# Dodla Dairy                    Packaged Foods
# Shyam Metalics   Iron & Steel/Interm.Products
# Sona BLW               Auto Parts & Equipment
# PowerGrid InvIT            Electric Utilities
# Macrotech Dev                          Realty
# Barbeque Nat                      Restaurants
# Nazara                   IT Software Products
# Suryoday Small                          Banks
# Kalyan Jeweller  Other Apparels & Accessories
# Laxmi Organic             Specialty Chemicals
# Craftsman                Industrial Machinery
# Anupam Rasayan            Specialty Chemicals
# Easy Trip             Travel Support Services
# MTAR Tech                Industrial Machinery
# Heranba                         Agrochemicals
# Railtel                      Telecom Services
# Nureca                    Healthcare Supplies
# Stove Kraft              Household Appliances
# Home First                    Housing Finance
# Indigo Paints     Furniture-Furnishing-Paints
# IRFC                Finance (including NBFCs)
# Antony Waste                            Other
# Bectors Food                   Packaged Foods
# Burger King                       Restaurants
# Gland                         Pharmaceuticals
# Equitas Bank                            Banks
# UTI AMC                 Asset Management Cos.
# Mazagon Dock                            Other
# Angel Broking        Other Financial Services
# CAMS                 Other Financial Services
# Chemcon Special           Specialty Chemicals
# Route                                Shipping
# Happiest Minds       IT Consulting & Software
# Rossari                   Specialty Chemicals
# SBI Card            Finance (including NBFCs)
# Prince Pipes                 Plastic Products
# Ujjivan Small                           Banks
# CSB Bank                                Banks
# IRCTC                 Travel Support Services
# Sterling & Wils                         Other
# Indiamart Inter                      Shipping
# Neogen                    Specialty Chemicals
# Metropolis                Healthcare Services
# Rail Vikas         Construction & Engineering
# Embassy Office                          Other
# MSTC                Finance (including NBFCs)
# Chalet Hotels                          Hotels
# Xelpmoc Design                          Other
# AAVAS Financier               Housing Finance
